# %% [markdown]
# # Week 1 - Iterating through data using Python
#
# ## A real data challenge – a massive dataset
#
# We want to explore `NYC EMS data since 2011`. We are saddled with a massive file that is `6+GB` that has `more than 26 million` rows of data. At this size, even Pandas will slow down dramatically.
#
# Our strategy is to `iterate` or `loop` through the data in smaller chunks and to analyze them. We will analyze the entire dataset and to get complete, reconstituted results that represent an analysis of the entire 6+GB of data.
#
# We need to learn a couple of fundamental Python techniques that will help us extend Pandas' abilities.

# %% [markdown]
# ### 1. ```for loops```... a data journalist's favorite Python expression</center>
#
# We can use a `for loop` to **iterate** (to do the same series of steps in a process over and over again), including:
# * running some calculation on each value stored in a list;
# * opening and reading a list of files;
# * literally an endless series of important tasks.

# %%
## name dog lucy
my_dog = "Lucy"

# %%
## upper case the previous variable 
## you can target an individual item
my_dog.upper()
# Out:
# 'LUCY'

# %%
## make it all lowercase
my_dog.lower()
# Out:
# 'lucy'

# %%
## run this list
fav_animals = ["dogs", "cats", "birds", "elephants"]

# %%
##call our list
fav_animals
# Out:
# ['dogs', 'cats', 'birds', 'elephants']

# %%
## upper case and print each animal in our list
## this will break
fav_animals.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 3
#       1 ## upper case and print each animal in our list
#       2 ## this will break
# ----> 3 fav_animals.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
## recall that we can slice a list

fav_animals[0]
# Out:
# 'dogs'

# %%
fav_animals[1:3]
# Out:
# ['cats', 'birds']

# %%
## we can target an individual item that has has been sliced from a list

fav_animals[0].upper()
# Out:
# 'DOGS'

# %%
# find type
## you can only do individual items in a list, but you can't do an entire list at once using this method. 
### another word for a list is an iterable. 

type(fav_animals)
# Out:
# list

# %% [markdown]
# **We can't do one at a time, but we can iterate through all of them using a `for loop`**

# %%
## use a for loop to upper case each animal and print it

for fav_animal in fav_animals:
    print(fav_animal.upper())
# Out:
# DOGS
# CATS
# BIRDS
# ELEPHANTS

# %% [markdown]
# ### What's happening in a `for loop`:
#
# <img src="https://sandeepmj.github.io/image-host/forloop3.png">

# %% [markdown]
# <img src="https://sandeepmj.github.io/image-host/forloop4.png">

# %% [markdown]
# <img src="https://sandeepmj.github.io/image-host/forloop5.png">

# %% [markdown]
# <img src="https://sandeepmj.github.io/image-host/forloop6.png">

# %% [markdown]
# <img src="https://sandeepmj.github.io/image-host/forloop7.png">

# %% [markdown]
# <img src="https://sandeepmj.github.io/image-host/forloop8.png">

# %% [markdown]
# <img src="https://sandeepmj.github.io/image-host/forloop9.png">

# %% [markdown]
# <img src="https://sandeepmj.github.io/image-host/forloop10.png">

# %% [markdown]
# # To recap:
# <img src="https://sandeepmj.github.io/image-host/forloop6.png">

# %%
## re run a for loop to upper case each animal and print it

for little_creature in fav_animals: 
    print(little_creature.title())
# Out:
# Dogs
# Cats
# Birds
# Elephants

# %%
## remember that once you call the temporary variable, it will call the last object within the list because that's the last item it looped through. 
## call little_creature
little_creature
# Out:
# 'elephants'

# %%
## did our list change? Call the fav_animals list
### no, it stayed the same. 

fav_animals
# Out:
# ['dogs', 'cats', 'birds', 'elephants']

# %% [markdown]
# ### 2.  `append()`
#
# The `append()` lets us append values to a new list. Even if the list does not exist, we can declare it and then append to it.
#
# ```python
#     new_list = []
#     new_list.append(some_value)
# ```

# %%
## We save our iterated data by adding to an empty list

upper_animals = []

# %%
## call upper animals
upper_animals
# Out:
# []

# %%
## what's the type

type(upper_animals)
# Out:
# list

# %%
## do the 'for loop' 

for fav_animal in fav_animals:
    upper_animals.append(fav_animal.upper())
    
## call it

upper_animals
# Out:
# ['DOGS', 'CATS', 'BIRDS', 'ELEPHANTS', 'DOGS', 'CATS', 'BIRDS', 'ELEPHANTS']

# %%
## find out the length 
len(upper_animals)
# Out:
# 8

# %% [markdown]
# ## Let's take **For Loops** for test drive:
#
# ### Combine different data points together
#
# #### You scrape some URLs and place them in a list called myURLS (provided below):

# %%
## run this cell to activate the list
myURLS = [
    'great-unique-data-1.html',
    'great-unique-data-2.html',
    'great-unique-data-3.html',
    'great-unique-data-4.html',
    'great-unique-data-5.html',
    'great-unique-data-6.html',
    'great-unique-data-7.html',
    'great-unique-data-8.html',
    'great-unique-data-9.html',
    'great-unique-data-10.html',
    'great-unique-data-11.html',
    'great-unique-data-12.html',
    'great-unique-data-13.html',
    'great-unique-data-14.html',
    'great-unique-data-15.html'
]

myURLS
# Out:
# ['great-unique-data-1.html',
#  'great-unique-data-2.html',
#  'great-unique-data-3.html',
#  'great-unique-data-4.html',
#  'great-unique-data-5.html',
#  'great-unique-data-6.html',
#  'great-unique-data-7.html',
#  'great-unique-data-8.html',
#  'great-unique-data-9.html',
#  'great-unique-data-10.html',
#  'great-unique-data-11.html',
#  'great-unique-data-12.html',
#  'great-unique-data-13.html',
#  'great-unique-data-14.html',
#  'great-unique-data-15.html']

# %% [markdown]
# ### * You realize that these URLs are missing the base of "http://www.importantsite.com/"
# ### * Use a ```for loop``` to join the base URL to every partial URL in your list.
# ### * Print each FULL URL
# It should look like: ```"http://www.importantsite.com/great-unique-data-14.html``` but with unique numbers

# %%
## for loop and print

for myURL in myURLS:
    print(myURL)
# Out:
# /

# %% [markdown]
# ### Update myURLS and store full URLS in a new list
#
# #### Instead of just printing the joined URLs, create a new list called ```full_URLS``` that holds the full URLs.

# %%
## store the updated values
base_url = "http://www.importantsite.com/"
base_url

full_urls = []
full_urls
# Out:
# []

# %%
## call the new list
for myURLS in base_url:
    full_urls.append(base_url + myURLS)
    
full_urls
# Out:
# ['http://www.importantsite.com/h',
#  'http://www.importantsite.com/t',
#  'http://www.importantsite.com/t',
#  'http://www.importantsite.com/p',
#  'http://www.importantsite.com/:',
#  'http://www.importantsite.com//',
#  'http://www.importantsite.com//',
#  'http://www.importantsite.com/w',
#  'http://www.importantsite.com/w',
#  'http://www.importantsite.com/w',
#  'http://www.importantsite.com/.',
#  'http://www.importantsite.com/i',
#  'http://www.importantsite.com/m',
#  'http://www.importantsite.com/p',
#  'http://www.importantsite.com/o',
#  'http://www.importantsite.com/r',
#  'http://www.importantsite.com/t',
#  'http://www.importantsite.com/a',
#  'http://www.importantsite.com/n',
#  'http://www.importantsite.com/t',
#  'http://www.importantsite.com/s',
#  'http://www.importantsite.com/i',
#  'http://www.importantsite.com/t',
#  'http://www.importantsite.com/e',
#  'http://www.importantsite.com/.',
#  'http://www.importantsite.com/c',
#  'http://www.importantsite.com/o',
#  'http://www.importantsite.com/m',
#  'http://www.importantsite.com//']

# %% [markdown]
# ### 3. Counting while iterating
#
# Often we need to increment a number to track progress of an iteration.

# %%
## counter without incrementing
my_counter = 1
for animal in fav_animals:
    print(f"Animal {my_counter} is {animal}")
    my_counter = my_counter + 1
# Out:
# Animal 1 is dogs
# Animal 2 is cats
# Animal 3 is birds
# Animal 4 is elephants

# %%
## counter that increments

# %% [markdown]
# ## Back to our EMS data challenge
#
# For those of you who don't have sufficient splace, I have created <a href="https://raw.githubusercontent.com/sandeepmj/datasets/main/ems-excerpt.csv">an excerpt</a> of the `6+GB` dataset that is `25MB` and holds 100,000 rows of data instead of millions of rows. Those using the excerpt, your strategy will break to take break 100,000-rows file and `chunk` it into 10K pieces.
#
# With the actual `6+GB` file, we'll break it into 500K chunks.

# %%
## import libraries
import pandas as pd

# %%
## take big csv and chunk it
row_size = 500_000
chunk_number = 1
for partial_df in pd.read_csv("EMS_Incident_Dispatch_Data_20240407.csv",
                             chunksize = row_size):
    print(partial_df)
# Out:
#         CAD_INCIDENT_ID       INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0             110010790  01/01/2011 02:19:47 AM               UNC
# 1             110010791  01/01/2011 02:19:49 AM               EDP
# 2             110010792  01/01/2011 02:19:52 AM            UNKNOW
# 3             110010793  01/01/2011 02:19:56 AM               UNC
# 4             110010794  01/01/2011 02:20:05 AM            INJURY
# ...                 ...                     ...               ...
# 499995        111210092  05/01/2011 12:30:22 AM            SPEVNT
# 499996        111210093  05/01/2011 12:30:24 AM              SICK
# 499997        111210094  05/01/2011 12:30:35 AM            INJURY
# 499998        111210095  05/01/2011 12:31:00 AM             ABDPN
# 499999        111210096  05/01/2011 12:31:09 AM            INJURY
#
#         INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 0                                 2             UNC
# 1                                 7             EDP
# 2                                 3          UNKNOW
# 3                                 2             UNC
# 4                                 5          INJURY
# ...                             ...             ...
# 499995                            8          SPEVNT
# 499996                            6            SICK
# 499997                            5          INJURY
# 499998                            5           ABDPN
# 499999                            5          INJURY
#
#         FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 0                               2    01/01/2011 02:21:14 AM
# 1                               7                       NaN
# 2                               3    01/01/2011 02:25:05 AM
# 3                               2    01/01/2011 02:20:31 AM
# 4                               5    01/01/2011 03:29:04 AM
# ...                           ...                       ...
# 499995                          8    05/01/2011 06:12:39 AM
# 499996                          6    05/01/2011 01:05:43 AM
# 499997                          5    05/01/2011 12:51:13 AM
# 499998                          5    05/01/2011 12:31:40 AM
# 499999                          5    05/01/2011 12:37:01 AM
#
#        VALID_DISPATCH_RSPNS_TIME_INDC  DISPATCH_RESPONSE_SECONDS_QY  \
# 0                                   Y                            87
# 1                                   N                             0
# 2                                   Y                           313
# 3                                   Y                            35
# 4                                   Y                          4139
# ...                               ...                           ...
# 499995                              Y                         20537
# 499996                              Y                          2119
# 499997                              Y                          1238
# 499998                              Y                            40
# 499999                              Y                           352
#
#        FIRST_ACTIVATION_DATETIME  ...  ZIPCODE POLICEPRECINCT  \
# 0         01/01/2011 02:21:31 AM  ...  10030.0           32.0
# 1                            NaN  ...  10029.0           25.0
# 2         01/01/2011 02:25:10 AM  ...  10016.0           14.0
# 3         01/01/2011 02:20:37 AM  ...  11213.0           77.0
# 4         01/01/2011 03:29:04 AM  ...  10022.0           18.0
# ...                          ...  ...      ...            ...
# 499995    05/01/2011 06:13:06 AM  ...      NaN            NaN
# 499996    05/01/2011 01:06:24 AM  ...  10014.0            6.0
# 499997    05/01/2011 12:52:18 AM  ...  10009.0            9.0
# 499998    05/01/2011 12:31:49 AM  ...  11413.0          105.0
# 499999    05/01/2011 12:37:08 AM  ...  10454.0           40.0
#
#         CITYCOUNCILDISTRICT  COMMUNITYDISTRICT COMMUNITYSCHOOLDISTRICT  \
# 0                       9.0              110.0                     5.0
# 1                       8.0              111.0                     4.0
# 2                       4.0              105.0                     2.0
# 3                      36.0              308.0                    17.0
# 4                       4.0              105.0                     2.0
# ...                     ...                ...                     ...
# 499995                  NaN                NaN                     NaN
# 499996                  3.0              102.0                     2.0
# 499997                  2.0              103.0                     1.0
# 499998                 31.0              413.0                    29.0
# 499999                  8.0              201.0                     7.0
#
#        CONGRESSIONALDISTRICT REOPEN_INDICATOR SPECIAL_EVENT_INDICATOR  \
# 0                       13.0                N                       N
# 1                       13.0                N                       N
# 2                       12.0                N                       N
# 3                        9.0                N                       N
# 4                       12.0                N                       N
# ...                      ...              ...                     ...
# 499995                   NaN                Y                       Y
# 499996                  10.0                N                       N
# 499997                  12.0                N                       N
# 499998                   5.0                N                       N
# 499999                  15.0                N                       N
#
#         STANDBY_INDICATOR TRANSFER_INDICATOR
# 0                       N                  N
# 1                       N                  N
# 2                       N                  N
# 3                       N                  N
# 4                       N                  N
# ...                   ...                ...
# 499995                  N                  N
# 499996                  N                  N
# 499997                  N                  N
# 499998                  N                  N
# 499999                  N                  N
#
# [500000 rows x 31 columns]
#         CAD_INCIDENT_ID       INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 500000        111210097  05/01/2011 12:31:09 AM              SICK
# 500001        111210098  05/01/2011 12:31:10 AM               UNC
# 500002        111210099  05/01/2011 12:31:26 AM              SICK
# 500003        111210100  05/01/2011 12:31:47 AM               UNC
# 500004        111210101  05/01/2011 12:31:59 AM              SICK
# ...                 ...                     ...               ...
# 999995        112870503  10/14/2011 04:34:25 AM            INJURY
# 999996        112870504  10/14/2011 04:35:31 AM               EDP
# 999997        112870505  10/14/2011 04:36:08 AM               EDP
# 999998        112870506  10/14/2011 04:36:26 AM              CARD
# 999999        112870507  10/14/2011 04:37:17 AM              CARD
#
#         INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 500000                            6            SICK
# 500001                            2             UNC
# 500002                            6            SICK
# 500003                            2             UNC
# 500004                            4            SICK
# ...                             ...             ...
# 999995                            4          INJURY
# 999996                            7             EDP
# 999997                            7             EDP
# 999998                            3            CARD
# 999999                            3            CARD
#
#         FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 500000                          6    05/01/2011 12:31:26 AM
# 500001                          2    05/01/2011 12:31:21 AM
# 500002                          6    05/01/2011 12:31:48 AM
# 500003                          2    05/01/2011 12:32:00 AM
# 500004                          4    05/01/2011 12:32:19 AM
# ...                           ...                       ...
# 999995                          4    10/14/2011 04:34:39 AM
# 999996                          7    10/14/2011 04:36:35 AM
# 999997                          7    10/14/2011 04:36:47 AM
# 999998                          3    10/14/2011 04:36:57 AM
# 999999                          3    10/14/2011 04:37:33 AM
#
#        VALID_DISPATCH_RSPNS_TIME_INDC  DISPATCH_RESPONSE_SECONDS_QY  \
# 500000                              Y                            17
# 500001                              Y                            11
# 500002                              Y                            22
# 500003                              Y                            13
# 500004                              Y                            20
# ...                               ...                           ...
# 999995                              Y                            14
# 999996                              Y                            64
# 999997                              Y                            39
# 999998                              Y                            31
# 999999                              Y                            16
#
#        FIRST_ACTIVATION_DATETIME  ...  ZIPCODE POLICEPRECINCT  \
# 500000    05/01/2011 12:31:37 AM  ...  11207.0           75.0
# 500001    05/01/2011 12:31:41 AM  ...  10014.0            6.0
# 500002    05/01/2011 12:32:02 AM  ...  11201.0           84.0
# 500003    05/01/2011 12:32:06 AM  ...  11206.0           90.0
# 500004    05/01/2011 12:32:28 AM  ...  11106.0          114.0
# ...                          ...  ...      ...            ...
# 999995    10/14/2011 04:35:04 AM  ...  11372.0          115.0
# 999996    10/14/2011 04:36:51 AM  ...  11235.0           60.0
# 999997    10/14/2011 04:36:53 AM  ...  11221.0           83.0
# 999998    10/14/2011 04:37:04 AM  ...  11216.0           77.0
# 999999    10/14/2011 04:37:40 AM  ...  10031.0           30.0
#
#         CITYCOUNCILDISTRICT  COMMUNITYDISTRICT COMMUNITYSCHOOLDISTRICT  \
# 500000                 42.0              305.0                    19.0
# 500001                  3.0              102.0                     2.0
# 500002                 33.0              302.0                    15.0
# 500003                 34.0              301.0                    14.0
# 500004                 26.0              401.0                    30.0
# ...                     ...                ...                     ...
# 999995                 25.0              403.0                    30.0
# 999996                 48.0              313.0                    21.0
# 999997                 34.0              304.0                    32.0
# 999998                 35.0              308.0                    17.0
# 999999                  7.0              109.0                     6.0
#
#        CONGRESSIONALDISTRICT REOPEN_INDICATOR SPECIAL_EVENT_INDICATOR  \
# 500000                   8.0                N                       N
# 500001                  10.0                N                       N
# 500002                   7.0                N                       N
# 500003                   7.0                N                       N
# 500004                  12.0                N                       N
# ...                      ...              ...                     ...
# 999995                  14.0                N                       N
# 999996                   8.0                N                       N
# 999997                   8.0                N                       N
# 999998                   9.0                N                       N
# 999999                  13.0                N                       N
#
#         STANDBY_INDICATOR TRANSFER_INDICATOR
# 500000                  N                  N
# 500001                  N                  N
# 500002                  N                  N
# 500003                  N                  N
# 500004                  N                  N
# ...                   ...                ...
# 999995                  N                  N
# 999996                  N                  N
# 999997                  N                  N
# 999998                  N                  N
# 999999                  N                  N
#
# [500000 rows x 31 columns]
#          CAD_INCIDENT_ID       INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 1000000        112870508  10/14/2011 04:38:04 AM            MVAINJ
# 1000001        112870509  10/14/2011 04:40:24 AM              DRUG
# 1000002        112870510  10/14/2011 04:40:29 AM              SICK
# 1000003        112870511  10/14/2011 04:44:39 AM               EDP
# 1000004        112870512  10/14/2011 04:46:56 AM              SICK
# ...                  ...                     ...               ...
# 1499995        120691391  03/09/2012 11:14:01 AM               EDP
# 1499996        120691392  03/09/2012 11:14:04 AM            ALTMEN
# 1499997        120691393  03/09/2012 11:14:06 AM            DIFFBR
# 1499998        120691394  03/09/2012 11:15:03 AM              SICK
# 1499999        120691395  03/09/2012 11:15:24 AM               UNC
#
#          INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 1000000                            4          MVAINJ
# 1000001                            4          ALTMEN
# 1000002                            6            SICK
# 1000003                            7             EDP
# 1000004                            6            SICK
# ...                              ...             ...
# 1499995                            4             EDP
# 1499996                            3          ALTMEN
# 1499997                            2          DIFFBR
# 1499998                            6            SICK
# 1499999                            2             UNC
#
#          FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 1000000                          4    10/14/2011 04:38:18 AM
# 1000001                          3    10/14/2011 04:40:38 AM
# 1000002                          6    10/14/2011 04:40:56 AM
# 1000003                          7    10/14/2011 04:45:04 AM
# 1000004                          6    10/14/2011 04:47:19 AM
# ...                            ...                       ...
# 1499995                          4    03/09/2012 11:21:04 AM
# 1499996                          3    03/09/2012 11:15:23 AM
# 1499997                          2    03/09/2012 11:14:28 AM
# 1499998                          6    03/09/2012 11:29:13 AM
# 1499999                          2    03/09/2012 11:15:51 AM
#
#         VALID_DISPATCH_RSPNS_TIME_INDC  DISPATCH_RESPONSE_SECONDS_QY  \
# 1000000                              Y                            14
# 1000001                              Y                            14
# 1000002                              Y                            27
# 1000003                              Y                            25
# 1000004                              Y                            23
# ...                                ...                           ...
# 1499995                              Y                           423
# 1499996                              Y                            79
# 1499997                              Y                            22
# 1499998                              Y                           850
# 1499999                              Y                            27
#
#         FIRST_ACTIVATION_DATETIME  ...  ZIPCODE POLICEPRECINCT  \
# 1000000    10/14/2011 04:38:28 AM  ...  11434.0          113.0
# 1000001    10/14/2011 04:40:44 AM  ...      NaN            NaN
# 1000002    10/14/2011 04:41:07 AM  ...  11358.0          109.0
# 1000003    10/14/2011 04:45:23 AM  ...  10009.0            9.0
# 1000004    10/14/2011 04:47:33 AM  ...  10040.0           34.0
# ...                           ...  ...      ...            ...
# 1499995    03/09/2012 11:21:20 AM  ...  10036.0           14.0
# 1499996    03/09/2012 11:15:39 AM  ...  10025.0           24.0
# 1499997    03/09/2012 11:14:37 AM  ...  10455.0           40.0
# 1499998    03/09/2012 11:29:27 AM  ...  10018.0           14.0
# 1499999    03/09/2012 11:16:13 AM  ...  11229.0           70.0
#
#          CITYCOUNCILDISTRICT  COMMUNITYDISTRICT COMMUNITYSCHOOLDISTRICT  \
# 1000000                 27.0              412.0                    29.0
# 1000001                  NaN                NaN                     NaN
# 1000002                 19.0              407.0                    25.0
# 1000003                  2.0              103.0                     1.0
# 1000004                 10.0              112.0                     6.0
# ...                      ...                ...                     ...
# 1499995                  3.0              104.0                     2.0
# 1499996                  6.0              107.0                     3.0
# 1499997                  8.0              201.0                     7.0
# 1499998                  3.0              105.0                     2.0
# 1499999                 45.0              314.0                    22.0
#
#         CONGRESSIONALDISTRICT REOPEN_INDICATOR SPECIAL_EVENT_INDICATOR  \
# 1000000                   5.0                N                       N
# 1000001                   NaN                N                       N
# 1000002                   6.0                N                       N
# 1000003                  12.0                N                       N
# 1000004                  13.0                N                       N
# ...                       ...              ...                     ...
# 1499995                  10.0                N                       N
# 1499996                  10.0                N                       N
# 1499997                  15.0                N                       N
# 1499998                  12.0                N                       N
# 1499999                   9.0                N                       N
#
#          STANDBY_INDICATOR TRANSFER_INDICATOR
# 1000000                  N                  N
# 1000001                  N                  N
# 1000002                  N                  N
# 1000003                  N                  N
# 1000004                  N                  N
# ...                    ...                ...
# 1499995                  N                  N
# 1499996                  N                  N
# 1499997                  N                  N
# 1499998                  N                  N
# 1499999                  N                  N
#
# [500000 rows x 31 columns]
#          CAD_INCIDENT_ID       INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 1500000        120691396  03/09/2012 11:16:29 AM              SICK
# 1500001        120691397  03/09/2012 11:16:51 AM            RESPIR
# 1500002        120691399  03/09/2012 11:17:09 AM               UNC
# 1500003        120691400  03/09/2012 11:18:24 AM              SICK
# 1500004        120691401  03/09/2012 11:18:28 AM               EDP
# ...                  ...                     ...               ...
# 1999995        122051979  07/23/2012 01:59:59 PM               UNC
# 1999996        122051980  07/23/2012 01:59:59 PM             ABDPN
# 1999997        122051981  07/23/2012 02:00:18 PM            RESPIR
# 1999998         60852564  03/26/2006 07:26:35 PM            INHALE
# 1999999        122051982  07/23/2012 02:00:43 PM            ALTMEN
#
#          INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 1500000                            6            SICK
# 1500001                            4          RESPIR
# 1500002                            2             UNC
# 1500003                            6            SICK
# 1500004                            7             EDP
# ...                              ...             ...
# 1999995                            2             UNC
# 1999996                            5           ABDPN
# 1999997                            4          RESPIR
# 1999998                            5          INHALE
# 1999999                            3          ALTMEN
#
#          FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 1500000                          6    03/09/2012 11:16:50 AM
# 1500001                          4    03/09/2012 11:17:48 AM
# 1500002                          2    03/09/2012 11:17:29 AM
# 1500003                          6    03/09/2012 11:18:57 AM
# 1500004                          7    03/09/2012 11:19:03 AM
# ...                            ...                       ...
# 1999995                          2    07/23/2012 02:01:05 PM
# 1999996                          5    07/23/2012 02:00:48 PM
# 1999997                          4    07/23/2012 02:01:48 PM
# 1999998                          5    03/26/2006 07:26:41 PM
# 1999999                          3    07/23/2012 02:00:57 PM
#
#         VALID_DISPATCH_RSPNS_TIME_INDC  DISPATCH_RESPONSE_SECONDS_QY  \
# 1500000                              Y                            21
# 1500001                              Y                            57
# 1500002                              Y                            20
# 1500003                              Y                            33
# 1500004                              Y                            35
# ...                                ...                           ...
# 1999995                              Y                            66
# 1999996                              Y                            49
# 1999997                              Y                            90
# 1999998                              Y                             6
# 1999999                              Y                            14
#
#         FIRST_ACTIVATION_DATETIME  ...  ZIPCODE POLICEPRECINCT  \
# 1500000    03/09/2012 11:17:51 AM  ...  10019.0           18.0
# 1500001    03/09/2012 11:17:58 AM  ...  11203.0           67.0
# 1500002    03/09/2012 11:17:35 AM  ...  10306.0          122.0
# 1500003    03/09/2012 11:19:04 AM  ...  11201.0           84.0
# 1500004    03/09/2012 11:19:51 AM  ...  11372.0          115.0
# ...                           ...  ...      ...            ...
# 1999995    07/23/2012 02:01:19 PM  ...  10027.0           28.0
# 1999996    07/23/2012 02:01:13 PM  ...  10468.0           52.0
# 1999997    07/23/2012 02:02:04 PM  ...  11411.0          105.0
# 1999998    03/26/2006 07:26:41 PM  ...  10468.0           52.0
# 1999999    07/23/2012 02:01:42 PM  ...  10458.0           52.0
#
#          CITYCOUNCILDISTRICT  COMMUNITYDISTRICT COMMUNITYSCHOOLDISTRICT  \
# 1500000                  3.0              105.0                     2.0
# 1500001                 41.0              317.0                    18.0
# 1500002                 50.0              502.0                    31.0
# 1500003                 33.0              302.0                    15.0
# 1500004                 21.0              403.0                    24.0
# ...                      ...                ...                     ...
# 1999995                  9.0              110.0                     5.0
# 1999996                 14.0              207.0                    10.0
# 1999997                 27.0              413.0                    29.0
# 1999998                 14.0              207.0                    10.0
# 1999999                 15.0              207.0                    10.0
#
#         CONGRESSIONALDISTRICT REOPEN_INDICATOR SPECIAL_EVENT_INDICATOR  \
# 1500000                  12.0                N                       N
# 1500001                   9.0                N                       N
# 1500002                  11.0                N                       N
# 1500003                   7.0                N                       N
# 1500004                  14.0                N                       N
# ...                       ...              ...                     ...
# 1999995                  13.0                N                       N
# 1999996                  15.0                N                       N
# 1999997                   5.0                N                       N
# 1999998                  15.0                N                       N
# 1999999                  13.0                N                       N
#
#          STANDBY_INDICATOR TRANSFER_INDICATOR
# 1500000                  N                  N
# 1500001                  N                  N
# 1500002                  N                  N
# 1500003                  N                  N
# 1500004                  N                  N
# ...                    ...                ...
# 1999995                  N                  N
# 1999996                  N                  N
# 1999997                  N                  N
# 1999998                  N                  N
# 1999999                  N                  N
#
# [500000 rows x 31 columns]
#          CAD_INCIDENT_ID       INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 2000000        122051983  07/23/2012 02:00:59 PM              SICK
# 2000001        122051984  07/23/2012 02:01:53 PM            DIFFBR
# 2000002        122051985  07/23/2012 02:02:17 PM            MVAINJ
# 2000003        122051986  07/23/2012 02:02:46 PM              SICK
# 2000004        122051987  07/23/2012 02:02:51 PM              CARD
# ...                  ...                     ...               ...
# 2499995        123461909  12/11/2012 01:54:59 PM              SICK
# 2499996        123461910  12/11/2012 01:55:12 PM             ABDPN
# 2499997        123461911  12/11/2012 01:55:55 PM            INJURY
# 2499998        123461913  12/11/2012 01:56:06 PM             ELECT
# 2499999        123461914  12/11/2012 01:56:17 PM              SICK
#
#          INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 2000000                            6            SICK
# 2000001                            2          DIFFBR
# 2000002                            4          MVAINJ
# 2000003                            6          ALTMEN
# 2000004                            3            CARD
# ...                              ...             ...
# 2499995                            6            SICK
# 2499996                            5           ABDPN
# 2499997                            5          INBLED
# 2499998                            3           ELECT
# 2499999                            6            SICK
#
#          FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 2000000                          6    07/23/2012 02:01:41 PM
# 2000001                          2    07/23/2012 02:02:26 PM
# 2000002                          4    07/23/2012 02:03:02 PM
# 2000003                          3    07/23/2012 02:03:38 PM
# 2000004                          3    07/23/2012 02:02:56 PM
# ...                            ...                       ...
# 2499995                          6    12/11/2012 01:55:29 PM
# 2499996                          5    12/11/2012 01:56:31 PM
# 2499997                          3    12/11/2012 01:56:42 PM
# 2499998                          3    12/11/2012 01:56:39 PM
# 2499999                          6    12/11/2012 01:57:11 PM
#
#         VALID_DISPATCH_RSPNS_TIME_INDC  DISPATCH_RESPONSE_SECONDS_QY  \
# 2000000                              Y                            42
# 2000001                              Y                            33
# 2000002                              Y                            45
# 2000003                              Y                            52
# 2000004                              Y                             5
# ...                                ...                           ...
# 2499995                              Y                            30
# 2499996                              Y                            79
# 2499997                              Y                            47
# 2499998                              Y                            33
# 2499999                              Y                            54
#
#         FIRST_ACTIVATION_DATETIME  ...  ZIPCODE POLICEPRECINCT  \
# 2000000    07/23/2012 02:01:51 PM  ...  10027.0           28.0
# 2000001    07/23/2012 02:02:46 PM  ...  11217.0           84.0
# 2000002    07/23/2012 02:03:08 PM  ...  11694.0          100.0
# 2000003    07/23/2012 02:03:54 PM  ...  10011.0           10.0
# 2000004    07/23/2012 02:03:05 PM  ...  10458.0           48.0
# ...                           ...  ...      ...            ...
# 2499995    12/11/2012 01:57:00 PM  ...  11419.0          106.0
# 2499996    12/11/2012 01:56:49 PM  ...  11231.0           76.0
# 2499997    12/11/2012 01:56:54 PM  ...  11222.0           94.0
# 2499998    12/11/2012 01:56:57 PM  ...  10010.0           13.0
# 2499999    12/11/2012 01:58:07 PM  ...  10314.0          121.0
#
#          CITYCOUNCILDISTRICT  COMMUNITYDISTRICT COMMUNITYSCHOOLDISTRICT  \
# 2000000                  9.0              110.0                     5.0
# 2000001                 33.0              302.0                    15.0
# 2000002                 32.0              414.0                    27.0
# 2000003                  3.0              104.0                     2.0
# 2000004                 15.0              206.0                    10.0
# ...                      ...                ...                     ...
# 2499995                 28.0              410.0                    27.0
# 2499996                 38.0              306.0                    15.0
# 2499997                 33.0              301.0                    14.0
# 2499998                  3.0              105.0                     2.0
# 2499999                 50.0              502.0                    31.0
#
#         CONGRESSIONALDISTRICT REOPEN_INDICATOR SPECIAL_EVENT_INDICATOR  \
# 2000000                  13.0                N                       N
# 2000001                   8.0                N                       N
# 2000002                   5.0                N                       N
# 2000003                  10.0                N                       N
# 2000004                  15.0                N                       N
# ...                       ...              ...                     ...
# 2499995                   5.0                N                       N
# 2499996                  10.0                N                       N
# 2499997                  12.0                N                       N
# 2499998                  12.0                N                       N
# 2499999                  11.0                N                       N
#
#          STANDBY_INDICATOR TRANSFER_INDICATOR
# 2000000                  N                  N
# 2000001                  N                  N
# 2000002                  N                  N
# 2000003                  N                  N
# 2000004                  N                  N
# ...                    ...                ...
# 2499995                  N                  N
# 2499996                  N                  N
# 2499997                  N                  N
# 2499998                  N                  N
# 2499999                  N                  N
#
# [500000 rows x 31 columns]
# /var/folders/t4/yhv9cps51w7bfdt0w1lkv1zm0000gn/T/ipykernel_6503/4016331687.py:4: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   for partial_df in pd.read_csv("EMS_Incident_Dispatch_Data_20240407.csv",
#          CAD_INCIDENT_ID       INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 2500000        123461915  12/11/2012 01:56:31 PM             OBMIS
# 2500001        123461916  12/11/2012 01:56:34 PM              DRUG
# 2500002        123461917  12/11/2012 01:56:36 PM              CARD
# 2500003        123461918  12/11/2012 01:57:41 PM             ABDPN
# 2500004        123461919  12/11/2012 01:58:08 PM             ABDPN
# ...                  ...                     ...               ...
# 2999995        131201490  04/30/2013 12:17:59 PM             OBLAB
# 2999996        131201491  04/30/2013 12:18:21 PM            INJURY
# 2999997        131201492  04/30/2013 12:18:35 PM            INJURY
# 2999998        131201493  04/30/2013 12:19:17 PM               EDP
# 2999999        131201494  04/30/2013 12:20:02 PM            SICPED
#
#          INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 2500000                            4           OBMIS
# 2500001                            4            DRUG
# 2500002                            3            CARD
# 2500003                            5           ABDPN
# 2500004                            5           ABDPN
# ...                              ...             ...
# 2999995                            5           OBLAB
# 2999996                            5          INJURY
# 2999997                            5          INJURY
# 2999998                            7             EDP
# 2999999                            4          SICPED
#
#          FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 2500000                          4    12/11/2012 01:57:35 PM
# 2500001                          4    12/11/2012 01:57:14 PM
# 2500002                          3    12/11/2012 01:57:08 PM
# 2500003                          5    12/11/2012 01:57:55 PM
# 2500004                          5    12/11/2012 01:58:18 PM
# ...                            ...                       ...
# 2999995                          5    04/30/2013 12:18:29 PM
# 2999996                          5    04/30/2013 12:18:47 PM
# 2999997                          5    04/30/2013 12:19:32 PM
# 2999998                          7    04/30/2013 12:32:07 PM
# 2999999                          4    04/30/2013 12:20:27 PM
#
#         VALID_DISPATCH_RSPNS_TIME_INDC  DISPATCH_RESPONSE_SECONDS_QY  \
# 2500000                              Y                            64
# 2500001                              Y                            40
# 2500002                              Y                            32
# 2500003                              Y                            14
# 2500004                              Y                            10
# ...                                ...                           ...
# 2999995                           true                            30
# 2999996                           true                            26
# 2999997                           true                            57
# 2999998                           true                           770
# 2999999                           true                            25
#
#         FIRST_ACTIVATION_DATETIME  ...  ZIPCODE POLICEPRECINCT  \
# 2500000    12/11/2012 01:57:41 PM  ...  11432.0          107.0
# 2500001    12/11/2012 01:57:32 PM  ...  11417.0          106.0
# 2500002    12/11/2012 01:57:41 PM  ...  10024.0           24.0
# 2500003    12/11/2012 01:58:03 PM  ...  11355.0          109.0
# 2500004    12/11/2012 01:58:34 PM  ...  11369.0          115.0
# ...                           ...  ...      ...            ...
# 2999995    04/30/2013 12:18:38 PM  ...   10,455           40.0
# 2999996    04/30/2013 12:18:53 PM  ...   11,211           90.0
# 2999997    04/30/2013 12:19:54 PM  ...   11,358          109.0
# 2999998    04/30/2013 12:32:19 PM  ...   11,224           60.0
# 2999999    04/30/2013 12:20:39 PM  ...   11,434          105.0
#
#          CITYCOUNCILDISTRICT  COMMUNITYDISTRICT COMMUNITYSCHOOLDISTRICT  \
# 2500000                 24.0              408.0                    29.0
# 2500001                 32.0              410.0                    27.0
# 2500002                  6.0              107.0                     3.0
# 2500003                 20.0              407.0                    25.0
# 2500004                 21.0              403.0                    24.0
# ...                      ...                ...                     ...
# 2999995                 17.0              201.0                     7.0
# 2999996                 34.0              301.0                    14.0
# 2999997                 20.0              407.0                    25.0
# 2999998                 47.0              313.0                    21.0
# 2999999                 31.0              413.0                    29.0
#
#         CONGRESSIONALDISTRICT REOPEN_INDICATOR SPECIAL_EVENT_INDICATOR  \
# 2500000                   6.0                N                       N
# 2500001                   5.0                N                       N
# 2500002                  10.0                N                       N
# 2500003                   6.0                N                       N
# 2500004                  14.0                N                       N
# ...                       ...              ...                     ...
# 2999995                  15.0            false                   false
# 2999996                   7.0            false                   false
# 2999997                   6.0            false                   false
# 2999998                   8.0            false                   false
# 2999999                   5.0            false                   false
#
#          STANDBY_INDICATOR TRANSFER_INDICATOR
# 2500000                  N                  N
# 2500001                  N                  N
# 2500002                  N                  N
# 2500003                  N                  N
# 2500004                  N                  N
# ...                    ...                ...
# 2999995              false              false
# 2999996              false              false
# 2999997              false              false
# 2999998              false              false
# 2999999              false              false
#
# [500000 rows x 31 columns]
#          CAD_INCIDENT_ID       INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 3000000        131201495  04/30/2013 12:20:15 PM              CARD
# 3000001        131201496  04/30/2013 12:20:30 PM            INBLED
# 3000002        131201497  04/30/2013 12:20:32 PM            INJURY
# 3000003        131201498  04/30/2013 12:20:37 PM             ABDPN
# 3000004        131201499  04/30/2013 12:20:48 PM            TRAUMA
# ...                  ...                     ...               ...
# 3499995        132512366  09/08/2013 04:11:50 PM              SICK
# 3499996        132512367  09/08/2013 04:13:02 PM             SEIZR
# 3499997        132512368  09/08/2013 04:13:50 PM            DIFFBR
# 3499998        132512370  09/08/2013 04:14:15 PM            TRAUMA
# 3499999        132512371  09/08/2013 04:14:40 PM            DIFFBR
#
#          INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 3000000                            3            CARD
# 3000001                            3          INBLED
# 3000002                            5          INJURY
# 3000003                            5           ABDPN
# 3000004                            2          TRAUMA
# ...                              ...             ...
# 3499995                            6            SICK
# 3499996                            3           SEIZR
# 3499997                            2          DIFFBR
# 3499998                            2          TRAUMA
# 3499999                            2          DIFFBR
#
#          FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 3000000                          3    04/30/2013 12:20:34 PM
# 3000001                          3    04/30/2013 12:20:48 PM
# 3000002                          5    04/30/2013 12:21:12 PM
# 3000003                          5    04/30/2013 12:21:00 PM
# 3000004                          2    04/30/2013 12:21:24 PM
# ...                            ...                       ...
# 3499995                          6    09/08/2013 04:12:05 PM
# 3499996                          3    09/08/2013 04:13:16 PM
# 3499997                          2    09/08/2013 04:14:01 PM
# 3499998                          2    09/08/2013 04:14:25 PM
# 3499999                          2    09/08/2013 04:15:01 PM
#
#         VALID_DISPATCH_RSPNS_TIME_INDC  DISPATCH_RESPONSE_SECONDS_QY  \
# 3000000                           true                            19
# 3000001                           true                            18
# 3000002                           true                            40
# 3000003                           true                            23
# 3000004                           true                            36
# ...                                ...                           ...
# 3499995                           true                            15
# 3499996                           true                            14
# 3499997                           true                            11
# 3499998                           true                            10
# 3499999                           true                            21
#
#         FIRST_ACTIVATION_DATETIME  ... ZIPCODE POLICEPRECINCT  \
# 3000000    04/30/2013 12:20:57 PM  ...  11,221           81.0
# 3000001    04/30/2013 12:20:55 PM  ...  10,022           18.0
# 3000002    04/30/2013 12:22:11 PM  ...  11,426          105.0
# 3000003    04/30/2013 12:21:07 PM  ...  10,038            5.0
# 3000004    04/30/2013 12:22:13 PM  ...  10,314          121.0
# ...                           ...  ...     ...            ...
# 3499995    09/08/2013 04:12:32 PM  ...  10,461           49.0
# 3499996    09/08/2013 04:13:30 PM  ...  10,453           46.0
# 3499997    09/08/2013 04:14:15 PM  ...  10,452           44.0
# 3499998    09/08/2013 04:14:29 PM  ...  11,375          112.0
# 3499999    09/08/2013 04:15:06 PM  ...  10,301          120.0
#
#          CITYCOUNCILDISTRICT  COMMUNITYDISTRICT COMMUNITYSCHOOLDISTRICT  \
# 3000000                 36.0              303.0                    16.0
# 3000001                  4.0              105.0                     2.0
# 3000002                 23.0              413.0                    26.0
# 3000003                  1.0              103.0                     2.0
# 3000004                 50.0              501.0                    31.0
# ...                      ...                ...                     ...
# 3499995                 13.0              211.0                    11.0
# 3499996                 14.0              205.0                    10.0
# 3499997                 16.0              204.0                     9.0
# 3499998                 29.0              406.0                    28.0
# 3499999                 49.0              501.0                    31.0
#
#         CONGRESSIONALDISTRICT REOPEN_INDICATOR SPECIAL_EVENT_INDICATOR  \
# 3000000                   8.0            false                   false
# 3000001                  12.0            false                   false
# 3000002                   3.0            false                   false
# 3000003                   7.0            false                   false
# 3000004                  11.0            false                   false
# ...                       ...              ...                     ...
# 3499995                  14.0            false                   false
# 3499996                  15.0            false                   false
# 3499997                  15.0            false                   false
# 3499998                   6.0            false                   false
# 3499999                  11.0            false                   false
#
#          STANDBY_INDICATOR TRANSFER_INDICATOR
# 3000000              false              false
# 3000001              false              false
# 3000002              false              false
# 3000003              false              false
# 3000004              false              false
# ...                    ...                ...
# 3499995              false              false
# 3499996              false              false
# 3499997              false              false
# 3499998              false              false
# 3499999              false              false
#
# [500000 rows x 31 columns]
# /var/folders/t4/yhv9cps51w7bfdt0w1lkv1zm0000gn/T/ipykernel_6503/4016331687.py:4: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   for partial_df in pd.read_csv("EMS_Incident_Dispatch_Data_20240407.csv",
#          CAD_INCIDENT_ID       INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 3500000        132512372  09/08/2013 04:14:43 PM               EDP
# 3500001        132512373  09/08/2013 04:16:27 PM             ABDPN
# 3500002        132512374  09/08/2013 04:16:34 PM             ABDPN
# 3500003        132512375  09/08/2013 04:16:54 PM            INJURY
# 3500004        132512376  09/08/2013 04:17:18 PM               UNC
# ...                  ...                     ...               ...
# 3999995        140250073  01/25/2014 12:26:13 AM            DIFFBR
# 3999996        140250074  01/25/2014 12:26:43 AM              SICK
# 3999997        140250076  01/25/2014 12:29:17 AM              DRUG
# 3999998        190021369  01/02/2019 10:04:11 AM              SICK
# 3999999        140250077  01/25/2014 12:29:40 AM            ASTHMB
#
#          INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 3500000                            7             EDP
# 3500001                            5           ABDPN
# 3500002                            5           ABDPN
# 3500003                            5          INJURY
# 3500004                            2             UNC
# ...                              ...             ...
# 3999995                            2          DIFFBR
# 3999996                            6            SICK
# 3999997                            4            DRUG
# 3999998                            6            SICK
# 3999999                            2          ASTHMB
#
#          FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 3500000                          7    09/08/2013 04:14:57 PM
# 3500001                          5    09/08/2013 04:16:39 PM
# 3500002                          5    09/08/2013 04:16:53 PM
# 3500003                          5    09/08/2013 04:17:20 PM
# 3500004                          2    09/08/2013 04:17:37 PM
# ...                            ...                       ...
# 3999995                          2    01/25/2014 12:26:26 AM
# 3999996                          6    01/25/2014 12:27:13 AM
# 3999997                          4    01/25/2014 12:29:38 AM
# 3999998                          6    01/02/2019 10:04:36 AM
# 3999999                          2    01/25/2014 12:29:56 AM
#
#         VALID_DISPATCH_RSPNS_TIME_INDC  DISPATCH_RESPONSE_SECONDS_QY  \
# 3500000                           true                            14
# 3500001                           true                            12
# 3500002                           true                            19
# 3500003                           true                            26
# 3500004                           true                            19
# ...                                ...                           ...
# 3999995                           true                            13
# 3999996                           true                            30
# 3999997                           true                            21
# 3999998                              Y                            25
# 3999999                           true                            16
#
#         FIRST_ACTIVATION_DATETIME  ...  ZIPCODE POLICEPRECINCT  \
# 3500000    09/08/2013 04:15:04 PM  ...   11,213           77.0
# ...
# 24500001    01/28/2023 09:23:20 AM  ...  10007.0            1.0
# 24500002    01/28/2023 09:23:16 AM  ...  11102.0          114.0
# 24500003    01/28/2023 09:26:32 AM  ...  11423.0          103.0
# 24500004    01/28/2023 09:24:07 AM  ...  10467.0           49.0
# ...                            ...  ...      ...            ...
# 24999995    05/26/2023 01:46:00 PM  ...  10453.0           46.0
# 24999996    05/26/2023 01:47:41 PM  ...  10016.0           13.0
# 24999997    05/26/2023 01:47:34 PM  ...  11222.0           94.0
# 24999998    05/26/2023 01:49:31 PM  ...  11691.0          101.0
# 24999999    05/26/2023 01:47:49 PM  ...  10308.0          122.0
#
#           CITYCOUNCILDISTRICT  COMMUNITYDISTRICT COMMUNITYSCHOOLDISTRICT  \
# 24500000                  9.0              110.0                     5.0
# 24500001                  1.0              101.0                     2.0
# 24500002                 22.0              401.0                    30.0
# 24500003                 27.0              412.0                    29.0
# 24500004                 15.0              211.0                    11.0
# ...                       ...                ...                     ...
# 24999995                 14.0              205.0                    10.0
# 24999996                  2.0              105.0                     2.0
# 24999997                 33.0              301.0                    14.0
# 24999998                 31.0              414.0                    27.0
# 24999999                 51.0              503.0                    31.0
#
#          CONGRESSIONALDISTRICT REOPEN_INDICATOR SPECIAL_EVENT_INDICATOR  \
# 24500000                  13.0                N                       N
# 24500001                  10.0                N                       N
# 24500002                  12.0                N                       N
# 24500003                   5.0                Y                       N
# 24500004                  14.0                N                       N
# ...                        ...              ...                     ...
# 24999995                  15.0                N                       N
# 24999996                  12.0                N                       N
# 24999997                  12.0                N                       N
# 24999998                   5.0                N                       N
# 24999999                  11.0                N                       N
#
#           STANDBY_INDICATOR TRANSFER_INDICATOR
# 24500000                  N                  N
# 24500001                  N                  N
# 24500002                  N                  N
# 24500003                  N                  N
# 24500004                  N                  N
# ...                     ...                ...
# 24999995                  N                  N
# 24999996                  N                  N
# 24999997                  N                  N
# 24999998                  N                  N
# 24999999                  N                  N
#
# [500000 rows x 31 columns]
#           CAD_INCIDENT_ID       INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 25000000        231462422  05/26/2023 01:47:37 PM              DRUG
# 25000001        231462423  05/26/2023 01:48:15 PM             ABDPN
# 25000002        231462425  05/26/2023 01:48:38 PM              CVAC
# 25000003        231462426  05/26/2023 01:48:43 PM              SICK
# 25000004        231462427  05/26/2023 01:48:50 PM            UNKNOW
# ...                   ...                     ...               ...
# 25499995        232583663  09/15/2023 06:14:42 PM              SICK
# 25499996        232583664  09/15/2023 06:14:47 PM            INJURY
# 25499997        232583665  09/15/2023 06:15:15 PM             OTHER
# 25499998        232583668  09/15/2023 06:16:08 PM               EDP
# 25499999        232583670  09/15/2023 06:16:17 PM              CARD
#
#           INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 25000000                            4            DRUG
# 25000001                            5           ABDPN
# 25000002                            2            CVAC
# 25000003                            6            SICK
# 25000004                            4          UNKNOW
# ...                               ...             ...
# 25499995                            6            SICK
# 25499996                            5            EDPC
# 25499997                            6           OTHER
# 25499998                            7            DRUG
# 25499999                            3            CARD
#
#           FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 25000000                          4    05/26/2023 01:47:47 PM
# 25000001                          5    05/26/2023 01:48:23 PM
# 25000002                          2    05/26/2023 01:49:04 PM
# 25000003                          6    05/26/2023 01:49:05 PM
# 25000004                          4    05/26/2023 01:48:57 PM
# ...                             ...                       ...
# 25499995                          6    09/15/2023 06:15:32 PM
# 25499996                          7    09/15/2023 06:14:57 PM
# 25499997                          6    09/15/2023 07:02:45 PM
# 25499998                          4    09/15/2023 06:16:26 PM
# 25499999                          3    09/15/2023 06:16:42 PM
#
#          VALID_DISPATCH_RSPNS_TIME_INDC  DISPATCH_RESPONSE_SECONDS_QY  \
# 25000000                              Y                            10
# 25000001                              Y                             8
# 25000002                              Y                            26
# 25000003                              Y                            22
# 25000004                              Y                             7
# ...                                 ...                           ...
# 25499995                              Y                            50
# 25499996                              Y                            10
# 25499997                              Y                          2850
# 25499998                              Y                            18
# 25499999                              Y                            25
#
#          FIRST_ACTIVATION_DATETIME  ...  ZIPCODE POLICEPRECINCT  \
# 25000000    05/26/2023 01:48:19 PM  ...  10022.0           17.0
# 25000001    05/26/2023 01:48:35 PM  ...  11226.0           67.0
# 25000002    05/26/2023 01:49:15 PM  ...  11411.0          105.0
# 25000003    05/26/2023 01:49:23 PM  ...  10029.0           23.0
# 25000004    05/26/2023 01:49:25 PM  ...  10036.0           14.0
# ...                            ...  ...      ...            ...
# 25499995    09/15/2023 06:16:28 PM  ...  10455.0           41.0
# 25499996    09/15/2023 06:15:15 PM  ...  11355.0          109.0
# 25499997    09/15/2023 07:02:55 PM  ...  10304.0          122.0
# 25499998    09/15/2023 06:17:23 PM  ...  10473.0           43.0
# 25499999    09/15/2023 06:17:14 PM  ...  10459.0           42.0
#
#           CITYCOUNCILDISTRICT  COMMUNITYDISTRICT COMMUNITYSCHOOLDISTRICT  \
# 25000000                  4.0              106.0                     2.0
# 25000001                 40.0              317.0                    17.0
# 25000002                 27.0              413.0                    29.0
# 25000003                  8.0              111.0                     4.0
# 25000004                  3.0              104.0                     2.0
# ...                       ...                ...                     ...
# 25499995                 17.0              202.0                     8.0
# 25499996                 20.0              407.0                    25.0
# 25499997                 50.0              502.0                    31.0
# 25499998                 18.0              209.0                     8.0
# 25499999                 17.0              203.0                    12.0
#
#          CONGRESSIONALDISTRICT REOPEN_INDICATOR SPECIAL_EVENT_INDICATOR  \
# 25000000                  12.0                N                       N
# 25000001                   9.0                N                       N
# 25000002                   5.0                N                       N
# 25000003                  13.0                N                       N
# 25000004                  10.0                N                       N
# ...                        ...              ...                     ...
# 25499995                  15.0                N                       N
# 25499996                   6.0                N                       N
# 25499997                  11.0                N                       N
# 25499998                  15.0                N                       N
# 25499999                  15.0                N                       N
#
#           STANDBY_INDICATOR TRANSFER_INDICATOR
# 25000000                  N                  N
# 25000001                  N                  N
# 25000002                  N                  N
# 25000003                  N                  N
# 25000004                  N                  N
# ...                     ...                ...
# 25499995                  N                  N
# 25499996                  N                  N
# 25499997                  N                  N
# 25499998                  N                  N
# 25499999                  N                  N
#
# [500000 rows x 31 columns]
#           CAD_INCIDENT_ID       INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 25500000        232583671  09/15/2023 06:16:22 PM              EDPC
# 25500001        232583672  09/15/2023 06:16:22 PM              DRUG
# 25500002        232583674  09/15/2023 06:17:15 PM             ABDPN
# 25500003        232583675  09/15/2023 06:17:16 PM            INJURY
# 25500004        232583677  09/15/2023 06:17:39 PM              SICK
# ...                   ...                     ...               ...
# 25984638        213414667  12/07/2021 11:56:43 PM            INJURY
# 25984639        213414668  12/07/2021 11:57:21 PM            SICMIN
# 25984640        213414669  12/07/2021 11:57:53 PM            SICKFC
# 25984641        213414670  12/07/2021 11:59:15 PM            DIFFBR
# 25984642        213414671  12/07/2021 11:59:38 PM            DIFFBR
#
#           INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 25500000                            7            EDPC
# 25500001                            4            DRUG
# 25500002                            5           ABDPN
# 25500003                            5            SAFE
# 25500004                            6            SICK
# ...                               ...             ...
# 25984638                            5          INJURY
# 25984639                            7          SICMIN
# 25984640                            6          SICKFC
# 25984641                            2          DIFFBR
# 25984642                            2          SICKFC
#
#           FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 25500000                          7                       NaN
# 25500001                          4    09/15/2023 06:18:40 PM
# 25500002                          5    09/15/2023 06:17:26 PM
# 25500003                          6                       NaN
# 25500004                          6    09/15/2023 06:18:40 PM
# ...                             ...                       ...
# 25984638                          5    12/07/2021 11:56:52 PM
# 25984639                          7    12/08/2021 12:01:10 AM
# 25984640                          6    12/07/2021 11:58:21 PM
# 25984641                          2    12/07/2021 11:59:39 PM
# 25984642                          6    12/08/2021 12:00:10 AM
#
#          VALID_DISPATCH_RSPNS_TIME_INDC  DISPATCH_RESPONSE_SECONDS_QY  \
# 25500000                              N                             0
# 25500001                              Y                           138
# 25500002                              Y                            11
# 25500003                              N                             0
# 25500004                              Y                            61
# ...                                 ...                           ...
# 25984638                              Y                             9
# 25984639                              Y                           229
# 25984640                              Y                            28
# 25984641                              Y                            24
# 25984642                              Y                            32
#
#          FIRST_ACTIVATION_DATETIME  ...  ZIPCODE POLICEPRECINCT  \
# 25500000                       NaN  ...  11206.0           90.0
# 25500001    09/15/2023 06:18:49 PM  ...  10036.0           18.0
# 25500002    09/15/2023 06:17:33 PM  ...  10468.0           50.0
# 25500003                       NaN  ...  11370.0          114.0
# 25500004    09/15/2023 06:19:03 PM  ...  10468.0           52.0
# ...                            ...  ...      ...            ...
# 25984638    12/07/2021 11:57:08 PM  ...  10002.0            5.0
# 25984639    12/08/2021 12:01:28 AM  ...  11101.0          114.0
# 25984640    12/07/2021 11:58:44 PM  ...  11434.0          113.0
# 25984641    12/08/2021 12:00:07 AM  ...  10466.0           47.0
# 25984642    12/08/2021 12:00:51 AM  ...  11357.0          109.0
#
#           CITYCOUNCILDISTRICT  COMMUNITYDISTRICT COMMUNITYSCHOOLDISTRICT  \
# 25500000                 34.0              301.0                    14.0
# 25500001                  3.0              105.0                     2.0
# 25500002                 14.0              208.0                    10.0
# 25500003                 22.0              401.0                     7.0
# 25500004                 14.0              207.0                    10.0
# ...                       ...                ...                     ...
# 25984638                  1.0              103.0                     2.0
# 25984639                 26.0              401.0                    30.0
# 25984640                 28.0              412.0                    28.0
# 25984641                 12.0              212.0                    11.0
# 25984642                 20.0              407.0                    25.0
#
#          CONGRESSIONALDISTRICT REOPEN_INDICATOR SPECIAL_EVENT_INDICATOR  \
# 25500000                   7.0                N                       N
# 25500001                  12.0                N                       N
# 25500002                  13.0                N                       N
# 25500003                  14.0                N                       N
# 25500004                  13.0                N                       N
# ...                        ...              ...                     ...
# 25984638                   7.0                N                       N
# 25984639                  12.0                Y                       N
# 25984640                   5.0                N                       N
# 25984641                  16.0                N                       N
# 25984642                   6.0                N                       N
#
#           STANDBY_INDICATOR TRANSFER_INDICATOR
# 25500000                  N                  N
# 25500001                  N                  N
# 25500002                  N                  N
# 25500003                  N                  N
# 25500004                  N                  N
# ...                     ...                ...
# 25984638                  N                  N
# 25984639                  N                  N
# 25984640                  N                  N
# 25984641                  N                  N
# 25984642                  N                  N
#
# [484643 rows x 31 columns]

# %%
## take a look at partial_df

partial_df
# Out:
#           CAD_INCIDENT_ID       INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 25500000        232583671  09/15/2023 06:16:22 PM              EDPC
# 25500001        232583672  09/15/2023 06:16:22 PM              DRUG
# 25500002        232583674  09/15/2023 06:17:15 PM             ABDPN
# 25500003        232583675  09/15/2023 06:17:16 PM            INJURY
# 25500004        232583677  09/15/2023 06:17:39 PM              SICK
# ...                   ...                     ...               ...
# 25984638        213414667  12/07/2021 11:56:43 PM            INJURY
# 25984639        213414668  12/07/2021 11:57:21 PM            SICMIN
# 25984640        213414669  12/07/2021 11:57:53 PM            SICKFC
# 25984641        213414670  12/07/2021 11:59:15 PM            DIFFBR
# 25984642        213414671  12/07/2021 11:59:38 PM            DIFFBR
#
#           INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 25500000                            7            EDPC
# 25500001                            4            DRUG
# 25500002                            5           ABDPN
# 25500003                            5            SAFE
# 25500004                            6            SICK
# ...                               ...             ...
# 25984638                            5          INJURY
# 25984639                            7          SICMIN
# 25984640                            6          SICKFC
# 25984641                            2          DIFFBR
# 25984642                            2          SICKFC
#
#           FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 25500000                          7                       NaN
# 25500001                          4    09/15/2023 06:18:40 PM
# 25500002                          5    09/15/2023 06:17:26 PM
# 25500003                          6                       NaN
# 25500004                          6    09/15/2023 06:18:40 PM
# ...                             ...                       ...
# 25984638                          5    12/07/2021 11:56:52 PM
# 25984639                          7    12/08/2021 12:01:10 AM
# 25984640                          6    12/07/2021 11:58:21 PM
# 25984641                          2    12/07/2021 11:59:39 PM
# 25984642                          6    12/08/2021 12:00:10 AM
#
#          VALID_DISPATCH_RSPNS_TIME_INDC  DISPATCH_RESPONSE_SECONDS_QY  \
# 25500000                              N                             0
# 25500001                              Y                           138
# 25500002                              Y                            11
# 25500003                              N                             0
# 25500004                              Y                            61
# ...                                 ...                           ...
# 25984638                              Y                             9
# 25984639                              Y                           229
# 25984640                              Y                            28
# 25984641                              Y                            24
# 25984642                              Y                            32
#
#          FIRST_ACTIVATION_DATETIME  ...  ZIPCODE POLICEPRECINCT  \
# 25500000                       NaN  ...  11206.0           90.0
# 25500001    09/15/2023 06:18:49 PM  ...  10036.0           18.0
# 25500002    09/15/2023 06:17:33 PM  ...  10468.0           50.0
# 25500003                       NaN  ...  11370.0          114.0
# 25500004    09/15/2023 06:19:03 PM  ...  10468.0           52.0
# ...                            ...  ...      ...            ...
# 25984638    12/07/2021 11:57:08 PM  ...  10002.0            5.0
# 25984639    12/08/2021 12:01:28 AM  ...  11101.0          114.0
# 25984640    12/07/2021 11:58:44 PM  ...  11434.0          113.0
# 25984641    12/08/2021 12:00:07 AM  ...  10466.0           47.0
# 25984642    12/08/2021 12:00:51 AM  ...  11357.0          109.0
#
#           CITYCOUNCILDISTRICT  COMMUNITYDISTRICT COMMUNITYSCHOOLDISTRICT  \
# 25500000                 34.0              301.0                    14.0
# 25500001                  3.0              105.0                     2.0
# 25500002                 14.0              208.0                    10.0
# 25500003                 22.0              401.0                     7.0
# 25500004                 14.0              207.0                    10.0
# ...                       ...                ...                     ...
# 25984638                  1.0              103.0                     2.0
# 25984639                 26.0              401.0                    30.0
# 25984640                 28.0              412.0                    28.0
# 25984641                 12.0              212.0                    11.0
# 25984642                 20.0              407.0                    25.0
#
#          CONGRESSIONALDISTRICT REOPEN_INDICATOR SPECIAL_EVENT_INDICATOR  \
# 25500000                   7.0                N                       N
# 25500001                  12.0                N                       N
# 25500002                  13.0                N                       N
# 25500003                  14.0                N                       N
# 25500004                  13.0                N                       N
# ...                        ...              ...                     ...
# 25984638                   7.0                N                       N
# 25984639                  12.0                Y                       N
# 25984640                   5.0                N                       N
# 25984641                  16.0                N                       N
# 25984642                   6.0                N                       N
#
#           STANDBY_INDICATOR TRANSFER_INDICATOR
# 25500000                  N                  N
# 25500001                  N                  N
# 25500002                  N                  N
# 25500003                  N                  N
# 25500004                  N                  N
# ...                     ...                ...
# 25984638                  N                  N
# 25984639                  N                  N
# 25984640                  N                  N
# 25984641                  N                  N
# 25984642                  N                  N
#
# [484643 rows x 31 columns]

# %%
## take a look at its info

partial_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 484643 entries, 25500000 to 25984642
# Data columns (total 31 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   CAD_INCIDENT_ID                 484643 non-null  int64
#  1   INCIDENT_DATETIME               484643 non-null  object
#  2   INITIAL_CALL_TYPE               484643 non-null  object
#  3   INITIAL_SEVERITY_LEVEL_CODE     484643 non-null  int64
#  4   FINAL_CALL_TYPE                 484643 non-null  object
#  5   FINAL_SEVERITY_LEVEL_CODE       484643 non-null  int64
#  6   FIRST_ASSIGNMENT_DATETIME       476522 non-null  object
#  7   VALID_DISPATCH_RSPNS_TIME_INDC  484643 non-null  object
#  8   DISPATCH_RESPONSE_SECONDS_QY    484643 non-null  int64
#  9   FIRST_ACTIVATION_DATETIME       475596 non-null  object
#  10  FIRST_ON_SCENE_DATETIME         459084 non-null  object
#  11  VALID_INCIDENT_RSPNS_TIME_INDC  484643 non-null  object
#  12  INCIDENT_RESPONSE_SECONDS_QY    458999 non-null  float64
#  13  INCIDENT_TRAVEL_TM_SECONDS_QY   459064 non-null  float64
#  14  FIRST_TO_HOSP_DATETIME          305965 non-null  object
#  15  FIRST_HOSP_ARRIVAL_DATETIME     304830 non-null  object
#  16  INCIDENT_CLOSE_DATETIME         484529 non-null  object
#  17  HELD_INDICATOR                  484643 non-null  object
#  18  INCIDENT_DISPOSITION_CODE       475231 non-null  float64
#  19  BOROUGH                         484643 non-null  object
#  20  INCIDENT_DISPATCH_AREA          484643 non-null  object
#  21  ZIPCODE                         479850 non-null  float64
#  22  POLICEPRECINCT                  479866 non-null  float64
#  23  CITYCOUNCILDISTRICT             479866 non-null  float64
#  24  COMMUNITYDISTRICT               479865 non-null  float64
#  25  COMMUNITYSCHOOLDISTRICT         479544 non-null  float64
#  26  CONGRESSIONALDISTRICT           479866 non-null  float64
#  27  REOPEN_INDICATOR                484643 non-null  object
#  28  SPECIAL_EVENT_INDICATOR         484643 non-null  object
#  29  STANDBY_INDICATOR               484643 non-null  object
#  30  TRANSFER_INDICATOR              484643 non-null  object
# dtypes: float64(9), int64(4), object(18)
# memory usage: 114.6+ MB

# %%
## take big csv and chunk it
row_size = 500_000
chunk_number = 1
for partial_df in pd.read_csv("EMS_Incident_Dispatch_Data_20240407.csv",
                             chunksize = row_size):
# Out:
#   Cell In[44], line 5
#     chunksize = row_size):
#                           ^
# SyntaxError: incomplete input

# %%
## call df_segment

# %%
## we can save a segment to a more manageable csv
partial_df.to_csv("test.csv",
                 encoding = "UTF-8",
                 index = False)

# %%
## we have to save each one as a file
### you include index = False because otherwise the file would keep creating new index columns. 

row_size = 500_000
chunk_number = 1
for partial_df in pd.read_csv("EMS_Incident_Dispatch_Data_20240407.csv",
                             chunksize = row_size):
    partial_df.to_csv(f"ems-data-{chunk_number}.csv",
                     encoding = "UTF-8",
                     index = False)
    chunk_number = chunk_number + 1
# Out:
# /var/folders/t4/yhv9cps51w7bfdt0w1lkv1zm0000gn/T/ipykernel_6503/2142387619.py:6: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   for partial_df in pd.read_csv("EMS_Incident_Dispatch_Data_20240407.csv",
# /var/folders/t4/yhv9cps51w7bfdt0w1lkv1zm0000gn/T/ipykernel_6503/2142387619.py:6: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   for partial_df in pd.read_csv("EMS_Incident_Dispatch_Data_20240407.csv",

# %%
## we have to save each one as a file

# %%
## what is the chunk number if you call it now?
chunk_number
# Out:
# 53

# %%
## save files as chunks

row_size = 500_000
chunk_number = 1
for partial_df in pd.read_csv("EMS_Incident_Dispatch_Data_20240407.csv",
                             chunksize = row_size):
    partial_df.to_csv

# %%
## let's look at one
test_df = pd.read_csv("ems-data-10.csv")
test_df.head()
# Out:
#    CAD_INCIDENT_ID       INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0        141603204  06/09/2014 06:47:28 PM               EDP
# 1        141603205  06/09/2014 06:47:35 PM               EDP
# 2        141603206  06/09/2014 06:47:36 PM            INJURY
# 3        141603207  06/09/2014 06:47:50 PM               UNC
# 4        141603208  06/09/2014 06:47:53 PM              DRUG
#
#    INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  FINAL_SEVERITY_LEVEL_CODE  \
# 0                            7            CARD                          3
# 1                            7             EDP                          7
# 2                            5          INJURY                          5
# 3                            2             UNC                          2
# 4                            4            DRUG                          4
#
#   FIRST_ASSIGNMENT_DATETIME VALID_DISPATCH_RSPNS_TIME_INDC  \
# 0    06/09/2014 06:48:03 PM                           true
# 1    06/09/2014 06:49:14 PM                           true
# 2    06/09/2014 06:47:45 PM                           true
# 3    06/09/2014 06:48:03 PM                           true
# 4    06/09/2014 06:48:23 PM                           true
#
#    DISPATCH_RESPONSE_SECONDS_QY FIRST_ACTIVATION_DATETIME  ...  ZIPCODE  \
# 0                            35    06/09/2014 06:48:13 PM  ...  10018.0
# 1                            99    06/09/2014 06:49:30 PM  ...  11233.0
# 2                             9    06/09/2014 06:48:02 PM  ...  11220.0
# 3                            13    06/09/2014 06:48:56 PM  ...  10302.0
# 4                            30    06/09/2014 06:48:34 PM  ...  10458.0
#
#   POLICEPRECINCT  CITYCOUNCILDISTRICT  COMMUNITYDISTRICT  \
# 0           14.0                  4.0              105.0
# 1           73.0                 41.0              316.0
# 2           72.0                 38.0              307.0
# 3          121.0                 49.0              501.0
# 4           46.0                 15.0              205.0
#
#   COMMUNITYSCHOOLDISTRICT CONGRESSIONALDISTRICT REOPEN_INDICATOR  \
# 0                     2.0                  12.0            false
# 1                    17.0                   9.0            false
# 2                    20.0                   7.0            false
# 3                    31.0                  11.0            false
# 4                    10.0                  15.0            false
#
#   SPECIAL_EVENT_INDICATOR  STANDBY_INDICATOR TRANSFER_INDICATOR
# 0                   false              false              false
# 1                   false              false              false
# 2                   false              false              false
# 3                   false              false              false
# 4                   false              false              false
#
# [5 rows x 31 columns]

# %%
## get big picture view
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 31 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   CAD_INCIDENT_ID                 500000 non-null  int64
#  1   INCIDENT_DATETIME               500000 non-null  object
#  2   INITIAL_CALL_TYPE               500000 non-null  object
#  3   INITIAL_SEVERITY_LEVEL_CODE     500000 non-null  int64
#  4   FINAL_CALL_TYPE                 500000 non-null  object
#  5   FINAL_SEVERITY_LEVEL_CODE       500000 non-null  int64
#  6   FIRST_ASSIGNMENT_DATETIME       496223 non-null  object
#  7   VALID_DISPATCH_RSPNS_TIME_INDC  500000 non-null  object
#  8   DISPATCH_RESPONSE_SECONDS_QY    500000 non-null  int64
#  9   FIRST_ACTIVATION_DATETIME       495150 non-null  object
#  10  FIRST_ON_SCENE_DATETIME         483230 non-null  object
#  11  VALID_INCIDENT_RSPNS_TIME_INDC  500000 non-null  object
#  12  INCIDENT_RESPONSE_SECONDS_QY    483135 non-null  float64
#  13  INCIDENT_TRAVEL_TM_SECONDS_QY   483230 non-null  float64
#  14  FIRST_TO_HOSP_DATETIME          348928 non-null  object
#  15  FIRST_HOSP_ARRIVAL_DATETIME     346139 non-null  object
#  16  INCIDENT_CLOSE_DATETIME         499704 non-null  object
#  17  HELD_INDICATOR                  500000 non-null  object
#  18  INCIDENT_DISPOSITION_CODE       495611 non-null  float64
#  19  BOROUGH                         500000 non-null  object
#  20  INCIDENT_DISPATCH_AREA          500000 non-null  object
#  21  ZIPCODE                         487476 non-null  float64
#  22  POLICEPRECINCT                  487498 non-null  float64
#  23  CITYCOUNCILDISTRICT             487217 non-null  float64
#  24  COMMUNITYDISTRICT               487498 non-null  float64
#  25  COMMUNITYSCHOOLDISTRICT         487412 non-null  float64
#  26  CONGRESSIONALDISTRICT           487217 non-null  float64
#  27  REOPEN_INDICATOR                500000 non-null  object
#  28  SPECIAL_EVENT_INDICATOR         500000 non-null  object
#  29  STANDBY_INDICATOR               500000 non-null  object
#  30  TRANSFER_INDICATOR              500000 non-null  object
# dtypes: float64(9), int64(4), object(18)
# memory usage: 118.3+ MB

# %%
## find all unique categories in 'INITIAL_CALL_TYPE'
test_df["INITIAL_CALL_TYPE"].unique()
# Out:
# array(['EDP', 'INJURY', 'UNC', 'DRUG', 'SICK', 'ABDPN', 'UNKNOW',
#        'STNDBY', 'DIFFBR', 'STATEP', 'ASTHMB', 'MEDRXN', 'CARD', 'OTHER',
#        'CHOKE', 'SHOT', 'PEDSTR', 'RESPIR', 'INJMAJ', 'STAB', 'OBMIS',
#        'OBMAJ', 'MVAINJ', 'INJMIN', 'ANAPH', 'ARREST', 'SEIZR', 'CVAC',
#        'HYPTN', 'CVA', 'GYNHEM', 'INJALS', 'MCI21P', 'ALTMEN', 'OBLAB',
#        'SICMIN', 'INBLED', 'BURNMA', 'SICPED', 'TRAUMA', 'EDPC', 'BURNMI',
#        'JUMPDN', 'INHALE', 'CARDBR', 'PEDFC', 'RAPE', 'OBOUT', 'SICKFC',
#        'OBCOMP', 'MCI21', 'JUMPUP', 'AMPMAJ', 'CHILDA', 'DROWN', 'PEDRF',
#        'MVA', 'PD13', 'ELECT', 'AMPMIN', 'COLD', 'CDBRFC', 'STRANS',
#        'GYNMAJ', 'DIFFFC', 'MCI43P', 'DIFFRF', 'ASTHFC', 'ABDPFC', 'HEAT',
#        'RESPFC', 'EDPM', 'MCI80P', 'VENOM', 'SICKRF', 'SPEVNT', 'T-SICK',
#        'PD13C', 'MEDVAC', 'T-TEXT', 'INBLFC', 'DOA', 'ALTMFC', 'SICMFC',
#        'MCI26P', 'MECHE', 'MCI32P', 'DRUGFC', 'SAFE', 'ANAPFC', 'UNCFC',
#        'MCI29P', 'CARDFC', 'STATFC', 'MCI77', 'ACC', 'MCI25P', 'MCI22P',
#        'FIRE75', 'UNCFT', 'SICKFT', 'ABDPFT', 'MCI42P', 'DIFFFT',
#        'RESPFT'], dtype=object)

# %%
## what are the unique injuries

# %%
## query and filter for venom and incident dates and boroughs

# %% [markdown]
# ### 4. `glob`
#
# Our goal is to analyze all the files, not a single subset.
#
# We need a way to `iterate` through all the files.
#
# A `list` is also known as an `iterable` because it contains items that can be **iterated over**.
#
# We need to take the chucked CSVs and store in a single list that we can then iterate over.
#
# We use a package called `glob` that globs all the files into a list.
#
# Let's see how it works:

# %%
## import libraries
import glob

# %% [markdown]
# ### The power of ```glob``` comes from its ability to gather any target files we want.

# %%
## grab only the csv files
## the star means that whatever value is actually listed their in the file name does not matter. 
myfile = glob.glob("ems-data-*.csv")
myfile
# Out:
# ['ems-data-40.csv',
#  'ems-data-41.csv',
#  'ems-data-43.csv',
#  'ems-data-8.csv',
#  'ems-data-9.csv',
#  'ems-data-42.csv',
#  'ems-data-52.csv',
#  'ems-data-46.csv',
#  'ems-data-47.csv',
#  'ems-data-45.csv',
#  'ems-data-51.csv',
#  'ems-data-50.csv',
#  'ems-data-44.csv',
#  'ems-data-23.csv',
#  'ems-data-37.csv',
#  'ems-data-36.csv',
#  'ems-data-22.csv',
#  'ems-data-34.csv',
#  'ems-data-20.csv',
#  'ems-data-21.csv',
#  'ems-data-35.csv',
#  'ems-data-19.csv',
#  'ems-data-31.csv',
#  'ems-data-25.csv',
#  'ems-data-24.csv',
#  'ems-data-30.csv',
#  'ems-data-18.csv',
#  'ems-data-26.csv',
#  'ems-data-32.csv',
#  'ems-data-33.csv',
#  'ems-data-27.csv',
#  'ems-data-16.csv',
#  'ems-data-17.csv',
#  'ems-data-15.csv',
#  'ems-data-29.csv',
#  'ems-data-28.csv',
#  'ems-data-14.csv',
#  'ems-data-38.csv',
#  'ems-data-10.csv',
#  'ems-data-11.csv',
#  'ems-data-39.csv',
#  'ems-data-13.csv',
#  'ems-data-12.csv',
#  'ems-data-49.csv',
#  'ems-data-2.csv',
#  'ems-data-3.csv',
#  'ems-data-48.csv',
#  'ems-data-1.csv',
#  'ems-data-4.csv',
#  'ems-data-5.csv',
#  'ems-data-7.csv',
#  'ems-data-6.csv']

# %%
# ## pip install natsort
# !pip install natsort
# Out:
# Collecting natsort
#   Obtaining dependency information for natsort from https://files.pythonhosted.org/packages/ef/82/7a9d0550484a62c6da82858ee9419f3dd1ccc9aa1c26a1e43da3ecd20b0d/natsort-8.4.0-py3-none-any.whl.metadata
#   Downloading natsort-8.4.0-py3-none-any.whl.metadata (21 kB)
# Downloading natsort-8.4.0-py3-none-any.whl (38 kB)
# Installing collected packages: natsort
# Successfully installed natsort-8.4.0

# %%
# ## import library and module
## natsort is the package, natsorted is the individual method being imported from that method. 
from natsort import natsorted

# %%
## sort in lexicographical order
myfiles = natsorted(glob.glob("ems-data-*.csv"))
myfiles
# Out:
# ['ems-data-1.csv',
#  'ems-data-2.csv',
#  'ems-data-3.csv',
#  'ems-data-4.csv',
#  'ems-data-5.csv',
#  'ems-data-6.csv',
#  'ems-data-7.csv',
#  'ems-data-8.csv',
#  'ems-data-9.csv',
#  'ems-data-10.csv',
#  'ems-data-11.csv',
#  'ems-data-12.csv',
#  'ems-data-13.csv',
#  'ems-data-14.csv',
#  'ems-data-15.csv',
#  'ems-data-16.csv',
#  'ems-data-17.csv',
#  'ems-data-18.csv',
#  'ems-data-19.csv',
#  'ems-data-20.csv',
#  'ems-data-21.csv',
#  'ems-data-22.csv',
#  'ems-data-23.csv',
#  'ems-data-24.csv',
#  'ems-data-25.csv',
#  'ems-data-26.csv',
#  'ems-data-27.csv',
#  'ems-data-28.csv',
#  'ems-data-29.csv',
#  'ems-data-30.csv',
#  'ems-data-31.csv',
#  'ems-data-32.csv',
#  'ems-data-33.csv',
#  'ems-data-34.csv',
#  'ems-data-35.csv',
#  'ems-data-36.csv',
#  'ems-data-37.csv',
#  'ems-data-38.csv',
#  'ems-data-39.csv',
#  'ems-data-40.csv',
#  'ems-data-41.csv',
#  'ems-data-42.csv',
#  'ems-data-43.csv',
#  'ems-data-44.csv',
#  'ems-data-45.csv',
#  'ems-data-46.csv',
#  'ems-data-47.csv',
#  'ems-data-48.csv',
#  'ems-data-49.csv',
#  'ems-data-50.csv',
#  'ems-data-51.csv',
#  'ems-data-52.csv']

# %%
## iterate through all the files and pull out "drug" incidents only
## once you run everything, it will store all of the drug-related rows into 'dataframes'
## append means to add to what was already there within the dataframe
dataframes = []
for myfile in myfiles:
    df = pd.read_csv(myfile)
    df["source"] = myfile
    temp_drug_df = df.query("INITIAL_CALL_TYPE == 'DRUG'")
    dataframes.append(temp_drug_df)
# Out:
# /var/folders/t4/yhv9cps51w7bfdt0w1lkv1zm0000gn/T/ipykernel_6503/626877014.py:6: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(myfile)
# /var/folders/t4/yhv9cps51w7bfdt0w1lkv1zm0000gn/T/ipykernel_6503/626877014.py:6: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(myfile)

# %%
## how many?
len(dataframes)
# Out:
# 52

# %%
## call a single one
dataframes[10]
# Out:
#         CAD_INCIDENT_ID       INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 1             142892746  10/16/2014 04:13:04 PM              DRUG
# 20            142892769  10/16/2014 04:17:37 PM              DRUG
# 65            142892824  10/16/2014 04:32:41 PM              DRUG
# 80            142892840  10/16/2014 04:37:39 PM              DRUG
# 126           142892889  10/16/2014 04:46:44 PM              DRUG
# ...                 ...                     ...               ...
# 499947        150583294  02/27/2015 07:38:53 PM              DRUG
# 499952        150583300  02/27/2015 07:40:50 PM              DRUG
# 499981        150583334  02/27/2015 07:49:44 PM              DRUG
# 499983        150583336  02/27/2015 07:50:49 PM              DRUG
# 499993        150583346  02/27/2015 07:53:13 PM              DRUG
#
#         INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 1                                 4            DRUG
# 20                                4            DRUG
# 65                                4             UNC
# 80                                4            DRUG
# 126                               4            DRUG
# ...                             ...             ...
# 499947                            4            DRUG
# 499952                            4            DRUG
# 499981                            4            DRUG
# 499983                            4            DRUG
# 499993                            4            DRUG
#
#         FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 1                               4    10/16/2014 04:13:19 PM
# 20                              4    10/16/2014 04:17:54 PM
# 65                              2    10/16/2014 04:32:59 PM
# 80                              4    10/16/2014 04:42:24 PM
# 126                             4    10/16/2014 04:47:07 PM
# ...                           ...                       ...
# 499947                          4    02/27/2015 07:39:39 PM
# 499952                          4    02/27/2015 07:41:30 PM
# 499981                          4    02/27/2015 07:50:19 PM
# 499983                          4    02/27/2015 07:51:00 PM
# 499993                          4    02/27/2015 07:56:08 PM
#
#        VALID_DISPATCH_RSPNS_TIME_INDC  DISPATCH_RESPONSE_SECONDS_QY  \
# 1                                true                            15
# 20                               true                            17
# 65                               true                            18
# 80                               true                           285
# 126                              true                            23
# ...                               ...                           ...
# 499947                           true                            46
# 499952                           true                            40
# 499981                           true                            35
# 499983                           true                            11
# 499993                           true                           175
#
#        FIRST_ACTIVATION_DATETIME  ... POLICEPRECINCT CITYCOUNCILDISTRICT  \
# 1         10/16/2014 04:13:39 PM  ...          113.0                27.0
# 20        10/16/2014 04:18:02 PM  ...          100.0                32.0
# 65        10/16/2014 04:33:16 PM  ...          105.0                23.0
# 80        10/16/2014 04:42:47 PM  ...           20.0                 6.0
# 126       10/16/2014 04:47:48 PM  ...           32.0                 9.0
# ...                          ...  ...            ...                 ...
# 499947    02/27/2015 07:40:06 PM  ...           20.0                 6.0
# 499952    02/27/2015 07:41:49 PM  ...           28.0                 9.0
# 499981    02/27/2015 07:50:46 PM  ...           48.0                15.0
# 499983    02/27/2015 07:51:14 PM  ...          115.0                21.0
# 499993    02/27/2015 07:56:29 PM  ...           40.0                 8.0
#
#         COMMUNITYDISTRICT  COMMUNITYSCHOOLDISTRICT CONGRESSIONALDISTRICT  \
# 1                   412.0                     29.0                   5.0
# 20                  414.0                     27.0                   5.0
# 65                  413.0                     29.0                   3.0
# 80                  107.0                      3.0                  10.0
# 126                 110.0                      5.0                  13.0
# ...                   ...                      ...                   ...
# 499947              107.0                      3.0                  10.0
# 499952              110.0                      3.0                  13.0
# 499981              206.0                     12.0                  15.0
# 499983              403.0                     30.0                  14.0
# 499993              201.0                      7.0                  15.0
#
#        REOPEN_INDICATOR SPECIAL_EVENT_INDICATOR STANDBY_INDICATOR  \
# 1                 false                   false             false
# 20                false                   false             false
# 65                false                   false             false
# 80                false                   false             false
# 126               false                   false             false
# ...                 ...                     ...               ...
# 499947            false                   false             false
# 499952            false                   false             false
# 499981            false                   false             false
# 499983            false                   false             false
# 499993            false                   false             false
#
#         TRANSFER_INDICATOR           source
# 1                    false  ems-data-11.csv
# 20                   false  ems-data-11.csv
# 65                   false  ems-data-11.csv
# 80                   false  ems-data-11.csv
# 126                  false  ems-data-11.csv
# ...                    ...              ...
# 499947               false  ems-data-11.csv
# 499952               false  ems-data-11.csv
# 499981               false  ems-data-11.csv
# 499983               false  ems-data-11.csv
# 499993               false  ems-data-11.csv
#
# [29622 rows x 32 columns]

# %%
## concat

df_drugs = pd.concat(dataframes, ignore_index = True)
df_drugs
# Out:
#          CAD_INCIDENT_ID       INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0              110010797  01/01/2011 02:20:17 AM              DRUG
# 1              110010800  01/01/2011 02:20:34 AM              DRUG
# 2              110010806  01/01/2011 02:21:23 AM              DRUG
# 3              110010811  01/01/2011 02:21:56 AM              DRUG
# 4              110010813  01/01/2011 02:22:24 AM              DRUG
# ...                  ...                     ...               ...
# 1478606        213414599  12/07/2021 11:30:56 PM              DRUG
# 1478607        213414609  12/07/2021 11:34:51 PM              DRUG
# 1478608        213414632  12/07/2021 11:44:15 PM              DRUG
# 1478609        213414660  12/07/2021 11:53:53 PM              DRUG
# 1478610        213414663  12/07/2021 11:54:12 PM              DRUG
#
#          INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 0                                  4            DRUG
# 1                                  4            DRUG
# 2                                  4            DRUG
# 3                                  4            DRUG
# 4                                  4          ARREST
# ...                              ...             ...
# 1478606                            4          ALTMEN
# 1478607                            4            DRUG
# 1478608                            4            DRUG
# 1478609                            4            DRUG
# 1478610                            4            DRUG
#
#          FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 0                                4    01/01/2011 02:40:16 AM
# 1                                4                       NaN
# 2                                4                       NaN
# 3                                4    01/01/2011 02:22:19 AM
# 4                                1    01/01/2011 02:22:51 AM
# ...                            ...                       ...
# 1478606                          3    12/07/2021 11:31:07 PM
# 1478607                          4    12/07/2021 11:34:58 PM
# 1478608                          4    12/07/2021 11:44:27 PM
# 1478609                          4    12/07/2021 11:54:56 PM
# 1478610                          4    12/07/2021 11:56:02 PM
#
#         VALID_DISPATCH_RSPNS_TIME_INDC  DISPATCH_RESPONSE_SECONDS_QY  \
# 0                                    Y                          1199
# 1                                    N                             0
# 2                                    N                             0
# 3                                    Y                            23
# 4                                    Y                            27
# ...                                ...                           ...
# 1478606                              Y                            11
# 1478607                              Y                             7
# 1478608                              Y                            12
# 1478609                              Y                            63
# 1478610                              Y                           110
#
#         FIRST_ACTIVATION_DATETIME  ... POLICEPRECINCT CITYCOUNCILDISTRICT  \
# 0          01/01/2011 02:40:27 AM  ...           41.0                17.0
# 1                             NaN  ...           18.0                 3.0
# 2                             NaN  ...            7.0                 2.0
# 3          01/01/2011 02:22:30 AM  ...          122.0                50.0
# 4          01/01/2011 02:22:58 AM  ...           90.0                34.0
# ...                           ...  ...            ...                 ...
# 1478606    12/07/2021 11:31:19 PM  ...           81.0                41.0
# 1478607    12/07/2021 11:35:07 PM  ...          121.0                49.0
# 1478608    12/07/2021 11:44:58 PM  ...           46.0                14.0
# 1478609    12/07/2021 11:57:58 PM  ...           14.0                 3.0
# 1478610    12/07/2021 11:56:16 PM  ...           17.0                 4.0
#
#          COMMUNITYDISTRICT  COMMUNITYSCHOOLDISTRICT CONGRESSIONALDISTRICT  \
# 0                    202.0                      8.0                  15.0
# 1                    104.0                      2.0                  10.0
# 2                    103.0                      1.0                  12.0
# 3                    502.0                     31.0                  11.0
# 4                    301.0                     14.0                   7.0
# ...                    ...                      ...                   ...
# 1478606              303.0                     16.0                   8.0
# 1478607              501.0                     31.0                  11.0
# 1478608              205.0                     10.0                  15.0
# 1478609              105.0                      2.0                  12.0
# 1478610              106.0                      2.0                  12.0
#
#         REOPEN_INDICATOR SPECIAL_EVENT_INDICATOR STANDBY_INDICATOR  \
# 0                      N                       N                 N
# 1                      N                       N                 N
# 2                      N                       N                 N
# 3                      N                       N                 N
# 4                      N                       N                 N
# ...                  ...                     ...               ...
# 1478606                N                       N                 N
# 1478607                N                       N                 N
# 1478608                N                       N                 N
# 1478609                N                       N                 N
# 1478610                N                       N                 N
#
#          TRANSFER_INDICATOR           source
# 0                         N   ems-data-1.csv
# 1                         N   ems-data-1.csv
# 2                         N   ems-data-1.csv
# 3                         N   ems-data-1.csv
# 4                         N   ems-data-1.csv
# ...                     ...              ...
# 1478606                   N  ems-data-52.csv
# 1478607                   N  ems-data-52.csv
# 1478608                   N  ems-data-52.csv
# 1478609                   N  ems-data-52.csv
# 1478610                   N  ems-data-52.csv
#
# [1478611 rows x 32 columns]

# %%
## see a sample, with random source list

# %%
## call a sample of 20

# %%
## filter venom with incident date and severity level code
df_drugs.filter(["INCIDENT_DATETIME", "INITIAL_SEVERITY_LEVEL_CODE","BOROUGH"])
# Out:
#               INCIDENT_DATETIME  INITIAL_SEVERITY_LEVEL_CODE  \
# 0        01/01/2011 02:20:17 AM                            4
# 1        01/01/2011 02:20:34 AM                            4
# 2        01/01/2011 02:21:23 AM                            4
# 3        01/01/2011 02:21:56 AM                            4
# 4        01/01/2011 02:22:24 AM                            4
# ...                         ...                          ...
# 1478606  12/07/2021 11:30:56 PM                            4
# 1478607  12/07/2021 11:34:51 PM                            4
# 1478608  12/07/2021 11:44:15 PM                            4
# 1478609  12/07/2021 11:53:53 PM                            4
# 1478610  12/07/2021 11:54:12 PM                            4
#
#                           BOROUGH
# 0                           BRONX
# 1                       MANHATTAN
# 2                       MANHATTAN
# 3        RICHMOND / STATEN ISLAND
# 4                        BROOKLYN
# ...                           ...
# 1478606                  BROOKLYN
# 1478607  RICHMOND / STATEN ISLAND
# 1478608                     BRONX
# 1478609                 MANHATTAN
# 1478610                 MANHATTAN
#
# [1478611 rows x 3 columns]

# %%
## value count by borough
df_drugs.value_counts("BOROUGH")
# Out:
# BOROUGH
# MANHATTAN                   502493
# BROOKLYN                    378179
# QUEENS                      276054
# BRONX                       268667
# RICHMOND / STATEN ISLAND     53213
# UNKNOWN                          5
# Name: count, dtype: int64

# %%
## percentage by borough

# %%
## iterate through all the files and pull out "final severity levels between 6 and 7 inclusive" incidents only

# %%
## see a sample, with random source list
